# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import sys
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.append("/Users/gabriel/Desktop/Quant_Project/Quant-Summer-Project")

from data.fetcher import fetch_data
from data.cleaner import clean_data
from data.loader import add_event_column
from config.settings import HISTORICAL_START,HISTORICAL_END

df_raw = fetch_data(HISTORICAL_START,HISTORICAL_END)
print(df_raw)
print(type(df_raw))

df_clean = clean_data(df_raw)

df_event = add_event_column(df_clean)

print(df_raw.null_count())
# Out:
# Hourly API request limit exceeded. Please try again in the next hour.
# dict_keys(['error', 'reason'])
# Error fetching data from https://archive-api.open-meteo.com/v1/archive with params {'latitude': 58.41, 'longitude': 15.62, 'timezone': 'Europe/Stockholm', 'start_date': '2000-01-01', 'end_date': '2024-12-31', 'daily': 'temperature_2m_max,temperature_2m_min,precipitation_sum'}: 'daily'
# None
# <class 'NoneType'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      14 df_raw = fetch_data(HISTORICAL_START,HISTORICAL_END)
#      15 print(df_raw)
#      16 print(type(df_raw))
#      17
# ---> 18 df_clean = clean_data(df_raw)
#      19
#      20 df_event = add_event_column(df_clean)
#      21
#
# File ~/Desktop/Quant_Project/Quant-Summer-Project/data/cleaner.py:7, in clean_data(df)
#       4 def clean_data(df):
#       5     # If the data is not correct format or are missing values , we need to clean the data and return a clean dataframe
#       6     # If its less than 5 nulls in a row --> interpolate , else --> discard the data
# ----> 7     orignal_length = len(df)
#       8     if df[
#       9         "time", "temperature_2m_max", "temperature_2m_min", "precipitation_sum"
#      10     ].is_empty():
#      11         return None
#
# TypeError: object of type 'NoneType' has no len()
