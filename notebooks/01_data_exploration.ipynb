# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import sys
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sys.path.append("/Users/gabriel/Desktop/Quant_Project/Quant-Summer-Project")

from data.fetcher import fetch_data
from data.cleaner import clean_data
from data.loader import add_event_column
from config.settings import HISTORICAL_START,HISTORICAL_END

df_raw = fetch_data(HISTORICAL_START,HISTORICAL_END)


df_clean = clean_data(df_raw)


df_event = add_event_column(df_clean)

# %%
df_temp = df_event["temperature_2m_max"].to_list()
df_year = df_event["time"].to_list()

plt.figure(figsize =(30,10))
plt.title(f"temperature_2m_max from {HISTORICAL_START} to {HISTORICAL_END} in Linköping")
plt.xlabel("date")
plt.ylabel("temperature_2m_max")


sns.lineplot(x = df_year , y = df_temp)
plt.xticks(ticks=range(0, len(df_year), 365), labels=[df_year[i][:4] for i in range(0, len(df_year), 365)], rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x11b104fb0>,
#   <matplotlib.axis.XTick at 0x11b1063c0>,
#   <matplotlib.axis.XTick at 0x11b202570>,
#   <matplotlib.axis.XTick at 0x11b202f90>,
#   <matplotlib.axis.XTick at 0x11b1051c0>,
#   <matplotlib.axis.XTick at 0x11b2005c0>,
#   <matplotlib.axis.XTick at 0x11b203d40>,
#   <matplotlib.axis.XTick at 0x11b1ec7a0>,
#   <matplotlib.axis.XTick at 0x11b203ec0>,
#   <matplotlib.axis.XTick at 0x11b1ed0d0>,
#   <matplotlib.axis.XTick at 0x11b1edb50>,
#   <matplotlib.axis.XTick at 0x11b1ee510>,
#   <matplotlib.axis.XTick at 0x11b1eef90>,
#   <matplotlib.axis.XTick at 0x11b1ef0e0>,
#   <matplotlib.axis.XTick at 0x11b1ef920>,
#   <matplotlib.axis.XTick at 0x11b280350>,
#   <matplotlib.axis.XTick at 0x11b280d70>,
#   <matplotlib.axis.XTick at 0x11b2817c0>,
#   <matplotlib.axis.XTick at 0x11b1ee6c0>,
#   <matplotlib.axis.XTick at 0x11b282120>,
#   <matplotlib.axis.XTick at 0x11b282b40>,
#   <matplotlib.axis.XTick at 0x11b283560>,
#   <matplotlib.axis.XTick at 0x11b283f50>,
#   <matplotlib.axis.XTick at 0x11b282db0>,
#   <matplotlib.axis.XTick at 0x11b230860>],
#  [Text(0, 0, '2000'),
#   Text(365, 0, '2001'),
#   Text(730, 0, '2002'),
#   Text(1095, 0, '2003'),
#   Text(1460, 0, '2004'),
#   Text(1825, 0, '2005'),
#   Text(2190, 0, '2006'),
#   Text(2555, 0, '2007'),
#   Text(2920, 0, '2008'),
#   Text(3285, 0, '2009'),
#   Text(3650, 0, '2010'),
#   Text(4015, 0, '2011'),
#   Text(4380, 0, '2012'),
#   Text(4745, 0, '2013'),
#   Text(5110, 0, '2014'),
#   Text(5475, 0, '2015'),
#   Text(5840, 0, '2016'),
#   Text(6205, 0, '2017'),
#   Text(6570, 0, '2018'),
#   Text(6935, 0, '2019'),
#   Text(7300, 0, '2020'),
#   Text(7665, 0, '2021'),
#   Text(8030, 0, '2022'),
#   Text(8395, 0, '2023'),
#   Text(8760, 0, '2024')])

# %% [markdown]
# We can clearly see similar temperature cycles every year. Some years show a slight difference in minimum temperature, but they also tend to peak slightly higher in maximum temperature compared to the average. In general, the temperature averages around 10°C, so this is the graph's baseline. This pattern repeats every year, reflecting the different seasons. Consequently, this allows us to predict future temperatures to some extent

# %%
plt.figure(figsize =(40,15))
plt.title(f"temperature_2m_max from {HISTORICAL_START} to {HISTORICAL_END} in Linköping Histogram")
plt.xlabel("temperature_2m_max")
sns.histplot(  x= df_temp,binwidth=0.5,kde =True)
# Out:
# <Axes: xlabel='temperature_2m_max', ylabel='Count'>

# %% [markdown]
# The data shows two peaks, which tells us this is a bimodal distribution. It rises from -10°C to approximately 6°C, drops back down, and then starts to rise again at 14°C, creating the second peak. It then reaches 20°C before dropping down again. This implies that certain models will perform poorly, specifically the Gaussian model. Consequently, we will build multiple models, using the assumption that a single Gaussian model will perform badly as our baseline.
# The reason this bimodal distribution appears is that we are mixing all the seasons together. Winter and summer create the two distinct peaks, while autumn and spring account for the temperatures in between and this is why the distribution dips between the two peaks.
